# %% [markdown]
# ### D Tale

# %% [markdown]
# D-Tale is a Python tool for interactive Exploratory Data Analysis (EDA).
# It lets you visually explore, filter, and analyze your pandas DataFrame in a web browser — showing statistics, missing values, correlations, and charts without writing extra code.

# %%
# !pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      -------------------------------------- 642.7/642.7 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   DEPRECATION: Building 'dash_daq' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'dash_daq'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   WARNING: The scripts futurize.exe and pasteurize.exe are installed in 'C:\Users\swami\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
# ...

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import dtale
dtale.show(df)
# Out:
# C:\Users\swami\AppData\Roaming\Python\Python313\site-packages\kaleido\_sync_server.py:11: UserWarning:
#
#
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
